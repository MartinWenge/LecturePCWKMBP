# %%
# %pylab notebook

import numpy as np
import math
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d.axes3d import Axes3D
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
def myPi(numIter=1000):
    incircle = 0
    xRand = np.random.uniform(0,1,numIter)
    yRand = np.random.uniform(0,1,numIter)
    for x,y in zip(xRand, yRand):
        if (x*x + y*y < 1):
            incircle +=1
    return 4*incircle/numIter

# %%
myPi()
# Out:
# 3.216

# %%
math.fabs(myPi(40000)-math.pi)/math.pi
# Out:
# 0.0023896625813751753

# %%
def funnyFunction(argX, argY):
    return argX*argX-argY*argY*argY+argX*argY*argY

# %%
fig = plt.figure(figsize=(8,6))

# `ax` is a 3D-aware axis instance, because of the projection='3d' keyword argument to add_subplot
ax = fig.add_subplot(1, 1, 1, projection='3d')
X=np.arange(-1,1,0.1)
Y=np.arange(-1,1,0.1)
X,Y = np.meshgrid(X,Y)
Z=funnyFunction(X,Y)

p = ax.plot_surface(X, Y, Z)
fig.show()
# Out:
# <img src="data:image/png;base64,..." width="799.5333333333333">
